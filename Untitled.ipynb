# %%
# !for file in $(ls ./fasta);do psiblast -query ./fasta/$file -db uniprot_sprot.fasta -evalue 0.01 \
-num_iterations 3 -out_ascii_pssm ./psiblast_training/${file:0:-6}.pssm -num_descriptions 10000 -num_alignments 10000 -out ./psiblast_training/${file:0:-6}.alns.blast ;done
# Out:
# ...
# ...
# ...

# %%
# !python script/pssmparse.py ./psiblast_training/

# %%
# !for file in $(ls ./psiblast_training/);do echo $file ;done
# Out:
# d1a12a_.alns.blast
# d1a12a_.prof
# d1a12a_.pssm
# d1a1xa_.alns.blast
# d1a1xa_.prof
# d1a1xa_.pssm
# d1a62a1.alns.blast
# d1a62a1.prof
# d1a62a1.pssm
# d1a9xa1.alns.blast
# d1a9xa1.prof
# d1a9xa1.pssm
# d1acoa1.alns.blast
# d1acoa1.prof
# d1acoa1.pssm
# d1acoa2.alns.blast
# d1acoa2.prof
# d1acoa2.pssm
# d1ad2a_.alns.blast
# d1ad2a_.prof
# d1ad2a_.pssm
# d1af7a1.alns.blast
# d1af7a1.prof
# d1af7a1.pssm
# d1ah7a_.alns.blast
# d1ah7a_.prof
# d1ah7a_.pssm
# d1aiea_.alns.blast
# d1aiea_.prof
# d1aiea_.pssm
# d1aola_.alns.blast
# d1aola_.prof
# d1aola_.pssm
# d1ayoa_.alns.blast
# d1ayoa_.prof
# d1ayoa_.pssm
# d1b0na1.alns.blast
# d1b0na1.prof
# d1b0na1.pssm
# d1b25a1.alns.blast
# d1b25a1.prof
# d1b25a1.pssm
# d1b25a2.alns.blast
# d1b25a2.prof
# d1b25a2.pssm
# d1b33n_.alns.blast
# d1b33n_.prof
# d1b33n_.pssm
# d1b79a_.alns.blast
# d1b79a_.prof
# d1b79a_.pssm
# d1bg1a1.alns.blast
# d1bg1a1.prof
# d1bg1a1.pssm
# d1bgfa_.alns.blast
# d1bgfa_.prof
# d1bgfa_.pssm
# d1bkra_.alns.blast
# ...
